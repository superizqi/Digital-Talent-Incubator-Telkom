# %% [markdown]
# ## Application of Clustering for Customer Segmentation
#
# Here we model the clustering model for customer segmentation from Mall Customer Data (https://www.kaggle.com/vjchoudhary7/customer-segmentation-tutorial-in-python). This data is consist of columns Gender, Age, Annual Income (k$), and Spending Score (1-100).
#
# We will do segmentation based on Gender, Age, Annual Income and Spending Score with KMeans Clustering and Hierarchial Clustering

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv('data/Mall_Customers.csv')
df_original = df.copy()
df = df.drop('CustomerID',axis=1)
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
# print dataset information, check null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
# print descriptive statistics
df.describe().transpose()
# Out:
#                         count   mean        std   min    25%   50%   75%  \
# Age                     200.0  38.85  13.969007  18.0  28.75  36.0  49.0
# Annual Income (k$)      200.0  60.56  26.264721  15.0  41.50  61.5  78.0
# Spending Score (1-100)  200.0  50.20  25.823522   1.0  34.75  50.0  73.0
#
#                           max
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %% [markdown]
# ### Data Preprocessing

# %%
# Label Encoding for Gender
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Gender'] = labelencoder.fit_transform(df['Gender'])
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %%
# Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit
col_names = df.columns.tolist()
scd = scaler.fit_transform(df[col_names])
df[col_names] = scd
df.head()
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0  1.128152 -1.424569           -1.738999               -0.434801
# 1  1.128152 -1.281035           -1.738999                1.195704
# 2 -0.886405 -1.352802           -1.700830               -1.715913
# 3 -0.886405 -1.137502           -1.700830                1.040418
# 4 -0.886405 -0.563369           -1.662660               -0.395980

# %% [markdown]
# ### Exploratory Data Analysis

# %%
sns.pairplot(data=df)

# %% [markdown]
# ### K-Means Clustering

# %% [markdown]
# #### Search for the optimum number of cluster (k)

# %%
# Transform Data Frame to Numpy Array
np_df = df.to_numpy()
# np_df
rr = range(2,30)
# Elbow Method
from sklearn.cluster import KMeans
wcss = []
for i in rr:
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(np_df)
    wcss.append(kmeans.inertia_)

# Visualize
plt.plot(rr,wcss)
plt.rcParams['figure.figsize'] = (16, 9)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
# Silhoutte Method
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
cls = []
slh_scr = []

for n_cluster in rr:
    kmeans = KMeans(n_clusters=n_cluster,random_state=0).fit(np_df)
    label = kmeans.labels_
    sil_coeff = silhouette_score(np_df, label, metric='euclidean')
    cls.append(n_cluster)
    slh_scr.append(sil_coeff)
#     print('For n_clusters={}, The Silhouette Coefficient is {}'.format(n_cluster, sil_coeff))

# Higher Better
abc = pd.DataFrame({'cluster' : cls, 'slh' : slh_scr})
abc = abc.sort_values(by='slh',ascending=False)
ncls = int(abc.reset_index().loc[0]['cluster'])
# ncls = 5
abc.head()
# Out:
#     cluster       slh
# 9        11  0.430990
# 11       13  0.430231
# 20       22  0.429051
# 19       21  0.427854
# 10       12  0.427588

# %% [markdown]
# Based on the results of the Elbow Method and Silhouette Method, it can be conclude that the most ideal number of clusters in this case study is **12 cluster**.

# %% [markdown]
# #### Modelling K-Means

# %%
# Modelling KMeans
# Apply the K-Means Model to the Data
kmeans = KMeans(n_clusters=ncls, init='k-means++', max_iter=300, n_init=10, random_state=0)
cluster = kmeans.fit_predict(np_df)

# %%
df['cluster-kmeans'] = cluster
df.head()
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0  1.128152 -1.424569           -1.738999               -0.434801
# 1  1.128152 -1.281035           -1.738999                1.195704
# 2 -0.886405 -1.352802           -1.700830               -1.715913
# 3 -0.886405 -1.137502           -1.700830                1.040418
# 4 -0.886405 -0.563369           -1.662660               -0.395980
#
#    cluster-kmeans
# 0              10
# 1              10
# 2               1
# 3               4
# 4               1

# %% [markdown]
# ### Hierarchial Clustering

# %% [markdown]
# #### Modelling Hierarchial Clustering

# %%
# Hierarchial Clusterring
import scipy.cluster.hierarchy as sch
dend = sch.dendrogram(sch.linkage(np_df, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Customer')
plt.ylabel('Euclidean')
plt.show()

# %%
# Apply the Hierarchical Clustering Model to the Dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=ncls, affinity='euclidean', linkage='ward')
hcluster = hc.fit_predict(np_df)

# %%
df['cluster-hierarchial'] = hcluster
df.head()
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0  1.128152 -1.424569           -1.738999               -0.434801
# 1  1.128152 -1.281035           -1.738999                1.195704
# 2 -0.886405 -1.352802           -1.700830               -1.715913
# 3 -0.886405 -1.137502           -1.700830                1.040418
# 4 -0.886405 -0.563369           -1.662660               -0.395980
#
#    cluster-kmeans  cluster-hierarchial
# 0              10                    0
# 1              10                    0
# 2               1                    9
# 3               4                    8
# 4               1                    9

# %% [markdown]
# ### Compare the result between k-means clustering and hierarchial clustering

# %%
dfc = df[['cluster-kmeans','cluster-hierarchial']]
dfc['compare'] = df['cluster-kmeans'] == df['cluster-hierarchial']
dfc.head()
# Out:
# <ipython-input-720-42ffeead078c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['compare'] = df['cluster-kmeans'] == df['cluster-hierarchial']
#    cluster-kmeans  cluster-hierarchial  compare
# 0              10                    0    False
# 1              10                    0    False
# 2               1                    9    False
# 3               4                    8    False
# 4               1                    9    False

# %%
# Difference cluster result between K-Means and Hierarchial Clustering
plt.pie(dfc['compare'].value_counts(), 
        colors = ['Red','Blue'], explode = [0, 0.1], 
        labels = ['False','True'], autopct = '%.2f%%')
plt.title('Difference cluster result between K-Means and Hierarchial Clustering', fontsize = 20)
plt.legend()
# plt.show()

# %% [markdown]
# According on the image above, it can be conclude that there is a difference with value **99.50%** for segmentation results based on the value of the cluster.

# %%
# Difference cluster result (by frequency) between K-Means and Hierarchial Clustering
dfc_freq = df['cluster-kmeans'].value_counts().to_frame()
dfc_freq = dfc_freq.reset_index().sort_values(by='index')
dfc_freq['cluster-hierarchial'] = df['cluster-hierarchial'].value_counts().to_frame().reset_index().sort_values(by='index')['cluster-hierarchial']
dfc_freq['compare'] = dfc_freq['cluster-kmeans'] == dfc_freq['cluster-hierarchial']
dfc_freq
# Out:
#     index  cluster-kmeans  cluster-hierarchial  compare
# 10      0               6                    4    False
# 9       1              13                   13     True
# 6       2              18                   18     True
# 4       3              21                   21     True
# 8       4              13                   13     True
# 1       5              25                   25     True
# 5       6              20                   18    False
# 3       7              21                   23    False
# 7       8              14                   15    False
# 0       9              26                   25    False
# 2      10              23                   25    False

# %%
# Difference cluster result between K-Means and Hierarchial Clustering
plt.pie(dfc_freq['compare'].value_counts(), 
        colors = ['Red','Blue'], explode = [0, 0.1], 
        labels = ['False','True'], autopct = '%.2f%%')
plt.title('Difference cluster result (By Freq) between K-Means and Hierarchial Clustering', fontsize = 20)
plt.legend()
# plt.show()

# %% [markdown]
# According on the image above, it can be conclude that there is a difference with value **54.55%** for segmentation results based on the frequency of each cluster.

# %%
def dt():
    abc = df_original.columns.tolist()
    abc.remove('CustomerID')
    return abc

# %%
sns.pairplot(data=df[dt()])

# %%
plt.rcParams['figure.figsize'] = (8, 5)
sns.scatterplot(data=df, x='Age', y='Spending Score (1-100)', hue='cluster-kmeans', palette='muted')

# %%
sns.scatterplot(data=df, x='Age', y='Annual Income (k$)', hue='cluster-kmeans', palette='muted')

# %%
sns.scatterplot(data=df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='cluster-kmeans', palette='muted')

# %%
# Below are the 11 cluster we found and each of their characteristics:
# df.describe().transpose()
dfp = df[['Gender','Age','Annual Income (k$)','Spending Score (1-100)','cluster-kmeans']]
dfp.head()
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0  1.128152 -1.424569           -1.738999               -0.434801
# 1  1.128152 -1.281035           -1.738999                1.195704
# 2 -0.886405 -1.352802           -1.700830               -1.715913
# 3 -0.886405 -1.137502           -1.700830                1.040418
# 4 -0.886405 -0.563369           -1.662660               -0.395980
#
#    cluster-kmeans
# 0              10
# 1              10
# 2               1
# 3               4
# 4               1

# %%
dfp[['Age','Annual Income (k$)','Spending Score (1-100)']] = df_original[['Age','Annual Income (k$)','Spending Score (1-100)']]
dfp.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  cluster-kmeans
# 0  1.128152   19                  15                      39              10
# 1  1.128152   21                  15                      81              10
# 2 -0.886405   20                  16                       6               1
# 3 -0.886405   23                  16                      77               4
# 4 -0.886405   31                  17                      40               1

# %%
clsn = []
gndr = []
agn = []
ann = []
spsn = []
for i in range(0,ncls):
    dss = dfp.loc[dfp['cluster-kmeans'] == i].describe()
    clsn.append(i)
    gndr.append(f"""{str(round(dss.describe()['Gender']['min'],2))} - {str(round(dss.describe()['Gender']['max'],2))}""")
    agn.append(f"""{str(round(dss.describe()['Age']['min'],2))} - {str(round(dss.describe()['Age']['max'],2))}""")
    ann.append(f"""{str(round(dss.describe()['Annual Income (k$)']['min'],2))} - {str(round(dss.describe()['Annual Income (k$)']['max'],2))}""")
    spsn.append(f"""{str(round(dss.describe()['Spending Score (1-100)']['min'],2))} - {str(round(dss.describe()['Spending Score (1-100)']['max'],2))}""")
pd.DataFrame({'Cluster' : clsn, 'Age' : agn, 'Annual Income' : ann, 'Spending Score' : spsn})
# Out:
#     Cluster           Age  Annual Income Spending Score
# 0         0    6.0 - 67.0     6.0 - 33.0     3.0 - 29.0
# 1         1  10.26 - 58.0    7.76 - 39.0     5.0 - 40.0
# 2         2   4.39 - 40.0   18.0 - 137.0    11.1 - 97.0
# 3         3   9.43 - 70.0    8.03 - 63.0    6.29 - 60.0
# 4         4   5.22 - 35.0    8.24 - 39.0    10.7 - 99.0
# 5         5   6.67 - 40.0   10.98 - 76.0    8.19 - 61.0
# 6         6  12.55 - 59.0  16.03 - 137.0     1.0 - 36.0
# 7         7   3.08 - 38.0  14.16 - 120.0    7.83 - 95.0
# 8         8   7.24 - 57.0   14.0 - 126.0     5.0 - 39.0
# 9         9   7.82 - 68.0    9.96 - 79.0     6.7 - 59.0
# 10       10   6.24 - 38.0    15.0 - 67.0   15.95 - 92.0

# %%
dfp = df[['Gender','Age','Annual Income (k$)','Spending Score (1-100)','cluster-hierarchial']]
dfp[['Age','Annual Income (k$)','Spending Score (1-100)']] = df_original[['Age','Annual Income (k$)','Spending Score (1-100)']]
clsn = []
gndr = []
agn = []
ann = []
spsn = []
for i in range(0,ncls):
    dss = dfp.loc[dfp['cluster-hierarchial'] == i].describe()
    clsn.append(i)
    gndr.append(f"""{str(round(dss.describe()['Gender']['min'],2))} - {str(round(dss.describe()['Gender']['max'],2))}""")
    agn.append(f"""{str(round(dss.describe()['Age']['min'],2))} - {str(round(dss.describe()['Age']['max'],2))}""")
    ann.append(f"""{str(round(dss.describe()['Annual Income (k$)']['min'],2))} - {str(round(dss.describe()['Annual Income (k$)']['max'],2))}""")
    spsn.append(f"""{str(round(dss.describe()['Spending Score (1-100)']['min'],2))} - {str(round(dss.describe()['Spending Score (1-100)']['max'],2))}""")
pd.DataFrame({'Cluster' : clsn, 'Age' : agn, 'Annual Income' : ann, 'Spending Score' : spsn})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#     Cluster           Age  Annual Income Spending Score
# 0         0   6.14 - 37.0    15.0 - 67.0    13.0 - 92.0
# 1         1  13.06 - 59.0  16.43 - 137.0     1.0 - 26.0
# 2         2  10.05 - 70.0   11.31 - 77.0    7.89 - 60.0
# 3         3   7.97 - 68.0    8.76 - 67.0    6.19 - 59.0
# 4         4   6.67 - 40.0   10.98 - 76.0    8.19 - 61.0
# 5         5   4.39 - 40.0   18.0 - 137.0    11.1 - 97.0
# 6         6   3.08 - 38.0  14.16 - 120.0    7.83 - 95.0
# 7         7   7.66 - 57.0   15.0 - 126.0     5.0 - 39.0
# 8         8   5.22 - 35.0    8.24 - 39.0    10.7 - 99.0
# ...

# %%
df['cluster-kmeans'].value_counts().sort_index().plot(kind='bar')

# %%
df['cluster-kmeans'].value_counts().sort_values()
# Out:
# 0      6
# 4     13
# 1     13
# 8     14
# 2     18
# 6     20
# 7     21
# 3     21
# 10    23
# 5     25
# 9     26
# Name: cluster-kmeans, dtype: int64

# %%
df['cluster-hierarchial'].value_counts().sort_index().plot(kind='bar')

# %%
df['cluster-hierarchial'].value_counts().sort_values()
# Out:
# 10     4
# 9     13
# 8     13
# 7     15
# 5     18
# 1     18
# 6     21
# 0     23
# 4     25
# 3     25
# 2     25
# Name: cluster-hierarchial, dtype: int64

# %% [markdown]
# ### Conclusion
#
# According to the results, it can be conclude that there are 11 clusters that do not have names, with each column value intervals according to their clusters.
#
# According to the results of K-Means clustering, we can can obtained Information that the highest frequency are in cluster 9 with frequency of 26 and the lowest frequency in cluster 0 with frequency of 6.
#
# According to the results of Hierarchial clustering, we can obtained Information that the the highest frequency are in clusters 2,3, and 4 with a frequency of 25 and the lowest frequency in cluster 10 with a frequency of 4.
